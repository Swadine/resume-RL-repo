# %%
# Clone the repository
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 2386, done.
# remote: Counting objects: 100% (2386/2386), done.
# remote: Compressing objects: 100% (1907/1907), done.
# remote: Total 2386 (delta 906), reused 1209 (delta 460), pack-reused 0
# Receiving objects: 100% (2386/2386), 97.65 MiB | 16.20 MiB/s, done.
# Resolving deltas: 100% (906/906), done.
# Updating files: 100% (2215/2215), done.
# /content/ml-agents
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 46.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 59.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pettingzoo: filename=PettingZoo-1.15.0-py3-none-any.whl size=875631 sha256=85fd137e17f482e437fa0db538beeff7da0e51e00f3d9c9d46db44733256a64e
# ...

# %%
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5" -O ./training-envs-executables/linux/SnowballTarget.zip && rm -rf /tmp/cookies.txt
# Out:
# --2024-01-04 15:32:05--  https://docs.google.com/uc?export=download&confirm=t&id=1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5
# Resolving docs.google.com (docs.google.com)... 172.217.194.101, 172.217.194.100, 172.217.194.138, ...
# Connecting to docs.google.com (docs.google.com)|172.217.194.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/htebg2jnnte6boaankv7feoam8tdpfne/1704382275000/15803371278684422230/*/1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5?e=download&uuid=d03e6a1a-2546-434b-a324-a30773ef271e [following]
# ...
# --2024-01-04 15:32:06--  https://doc-14-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/htebg2jnnte6boaankv7feoam8tdpfne/1704382275000/15803371278684422230/*/1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5?e=download&uuid=d03e6a1a-2546-434b-a324-a30773ef271e
# ...

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/SnowballTarget.zip

# %%
# !chmod -R 755 ./training-envs-executables/linux/SnowballTarget

# %%
# !mlagents-learn ./config/ppo/SnowballTarget.yaml --env=./training-envs-executables/linux/SnowballTarget/SnowballTarget --run-id="SnowballTarget1" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !mlagents-push-to-hf  --run-id="SnowballTarget1"  --local-dir="/content/ml-agents/results/SnowballTarget1"  --repo-id="Swadine/ppo-SnowballTarget"  --commit-message="ppo-Snowball agent"
# Out:
# [INFO] This function will create a model card and upload your SnowballTarget1 into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SnowballTarget1 to the Hugging Face Hub
# SnowballTarget.onnx:   0% 0.00/651k [00:00<?, ?B/s]
# SnowballTarget-199984.pt:   0% 0.00/3.85M [00:00<?, ?B/s]
#
# SnowballTarget-149984.onnx:   0% 0.00/651k [00:00<?, ?B/s]
#
#
# SnowballTarget-149984.pt:   0% 0.00/3.85M [00:00<?, ?B/s]
#
#
#
# SnowballTarget.onnx:   0% 0.00/651k [00:00<?, ?B/s]
#
#
#
#
# SnowballTarget.onnx:   3% 16.4k/651k [00:00<00:16, 39.2kB/s]
#
# SnowballTarget-149984.onnx:   3% 16.4k/651k [00:00<00:16, 39.4kB/s]
#
#
# SnowballTarget-149984.pt:   0% 16.4k/3.85M [00:00<01:43, 37.0kB/s]
# SnowballTarget-199984.pt:   0% 16.4k/3.85M [00:00<01:45, 36.4kB/s]
#
#
#
# SnowballTarget.onnx:   3% 16.4k/651k [00:00<00:17, 35.5kB/s]
#
#
# SnowballTarget-149984.pt:  45% 1.72M/3.85M [00:00<00:00, 3.95MB/s]
# ...
